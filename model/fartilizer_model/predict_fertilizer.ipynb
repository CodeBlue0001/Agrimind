# %%
import joblib
import pandas as pd

# %%
df=pd.read_csv(r"D:\researrch\agree.culture.Ai\code\dataset\Fertilizer Prediction.csv")
df.head()
# Out:
#    Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0           26         52        38     Sandy      Maize        37          0
# 1           29         52        45     Loamy  Sugarcane        12          0
# 2           34         65        62     Black     Cotton         7          9
# 3           32         62        34       Red    Tobacco        22          0
# 4           28         54        46    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea

# %%
try:
    Load_fertilizer_predictor=joblib.load(r"D:\researrch\agree.culture.Ai\code\model\fartilizer_model\fertilizer_prediction_model.pkl")
    Load_fertilizer_encoder=joblib.load(r"D:\researrch\agree.culture.Ai\code\model\fartilizer_model\fertilizer_label_encoder.pkl")
    print("Model successfully loaded")
except:
    print("model loading Failed!!")

sampel_test_data=pd.DataFrame([
    {
     'Temparature':29,
     'Moisture':50,
     'Soil Type':'Sandy',
     'Crop Type':'Maize',
     'Nitrogen':2,
     'Potassium':10,
     'Phosphorous':20 ,
    }
])
predicted_encoded_data=Load_fertilizer_predictor.predict(sampel_test_data)
predicted_fertilizer=Load_fertilizer_encoder.inverse_transform(predicted_encoded_data)
print("The predicted fertilizer is ",predicted_fertilizer[0])
# Out:
# Model successfully loaded
# The predicted fertilizer is  14-35-14
